# %%
#Q2-part1: How many times did the winning team score first in games vs non-wining teams?

# %%
import pandas as pd
import numpy as np

# %%
tournament_data= pd.read_csv('tournaments.csv')
goals_data= pd.read_csv('goals.csv')

# %%
#tournament_data.loc[ tournament_data['winner']== "West Germany", 'winner' ] = 'Germany'
tournament_data
# Out:
#     key_id tournament_id      tournament_name  year  start_date    end_date  \
# 0        1       WC-1930  1930 FIFA World Cup  1930  1930-07-13  1930-07-30
# 1        2       WC-1934  1934 FIFA World Cup  1934  1934-05-27  1934-06-10
# 2        3       WC-1938  1938 FIFA World Cup  1938  1938-06-04  1938-06-19
# 3        4       WC-1950  1950 FIFA World Cup  1950  1950-06-24  1950-07-16
# 4        5       WC-1954  1954 FIFA World Cup  1954  1954-06-16  1954-07-04
# 5        6       WC-1958  1958 FIFA World Cup  1958  1958-06-08  1958-06-29
# 6        7       WC-1962  1962 FIFA World Cup  1962  1962-05-30  1962-07-17
# 7        8       WC-1966  1966 FIFA World Cup  1966  1966-07-11  1966-07-30
# 8        9       WC-1970  1970 FIFA World Cup  1970  1970-05-31  1970-06-21
# 9       10       WC-1974  1974 FIFA World Cup  1974  1974-06-13  1974-07-07
# 10      11       WC-1978  1978 FIFA World Cup  1978  1978-06-01  1978-06-25
# 11      12       WC-1982  1982 FIFA World Cup  1982  1982-06-13  1982-07-11
# 12      13       WC-1986  1986 FIFA World Cup  1986  1986-05-31  1986-06-29
# 13      14       WC-1990  1990 FIFA World Cup  1990  1990-06-08  1990-07-08
# 14      15       WC-1994  1994 FIFA World Cup  1994  1994-06-17  1994-07-17
# 15      16       WC-1998  1998 FIFA World Cup  1998  1998-06-10  1998-07-12
# 16      17       WC-2002  2002 FIFA World Cup  2002  2002-05-31  2002-06-30
# 17      18       WC-2006  2006 FIFA World Cup  2006  2006-06-09  2006-07-09
# 18      19       WC-2010  2010 FIFA World Cup  2010  2010-06-11  2010-07-11
# 19      20       WC-2014  2014 FIFA World Cup  2014  2014-06-12  2014-07-13
# 20      21       WC-2018  2018 FIFA World Cup  2018  2018-06-14  2018-07-15
#
#      host_country        winner  host_won  count_teams  group_stage  \
# 0         Uruguay       Uruguay         1           13            1
# 1           Italy         Italy         1           16            0
# 2          France         Italy         0           15            0
# 3          Brazil       Uruguay         0           13            1
# 4     Switzerland  West Germany         0           16            1
# 5          Sweden        Brazil         0           16            1
# 6           Chile        Brazil         0           16            1
# 7         England       England         1           16            1
# 8          Mexico        Brazil         0           16            1
# 9    West Germany  West Germany         1           16            1
# 10      Argentina     Argentina         1           16            1
# 11          Spain         Italy         0           24            1
# 12         Mexico     Argentina         0           24            1
# 13          Italy  West Germany         0           24            1
# 14  United States        Brazil         0           24            1
# 15         France        France         1           32            1
# 16   Korea, Japan        Brazil         0           32            1
# 17        Germany         Italy         0           32            1
# 18   South Africa         Spain         0           32            1
# 19         Brazil       Germany         0           32            1
# 20         Russia        France         0           32            1
#
#     second_group_stage  final_round  round_of_16  quarter_finals  semi_finals  \
# 0                    0            0            0               0            1
# 1                    0            0            1               1            1
# 2                    0            0            1               1            1
# 3                    0            1            0               0            0
# 4                    0            0            0               1            1
# 5                    0            0            0               1            1
# 6                    0            0            0               1            1
# 7                    0            0            0               1            1
# 8                    0            0            0               1            1
# 9                    1            0            0               0            0
# 10                   1            0            0               0            0
# 11                   1            0            0               0            1
# 12                   0            0            1               1            1
# 13                   0            0            1               1            1
# 14                   0            0            1               1            1
# 15                   0            0            1               1            1
# 16                   0            0            1               1            1
# 17                   0            0            1               1            1
# 18                   0            0            1               1            1
# 19                   0            0            1               1            1
# 20                   0            0            1               1            1
#
#     third_place_match  final
# 0                   0      1
# 1                   1      1
# 2                   1      1
# 3                   0      0
# 4                   1      1
# 5                   1      1
# 6                   1      1
# 7                   1      1
# 8                   1      1
# 9                   1      1
# 10                  1      1
# 11                  1      1
# 12                  1      1
# 13                  1      1
# 14                  1      1
# 15                  1      1
# 16                  1      1
# 17                  1      1
# 18                  1      1
# 19                  1      1
# 20                  1      1

# %%
tournament_data=tournament_data.rename(columns={'winner': 'first_goal_country'})
#tournament_data

# %%
goals_data['team1']=goals_data['match_name'].apply( lambda x: x.split(' v ')[0])
goals_data['team2']=goals_data['match_name'].apply( lambda x: x.split(' v ')[1])
#goals_data.head(15)

# %%
pd.set_option( 'display.max_columns', None )
goals_data.head()
# Out:
#    key_id goal_id tournament_id      tournament_name   match_id  \
# 0       1  G-0001       WC-1930  1930 FIFA World Cup  M-1930-01
# 1       2  G-0002       WC-1930  1930 FIFA World Cup  M-1930-01
# 2       3  G-0003       WC-1930  1930 FIFA World Cup  M-1930-01
# 3       4  G-0004       WC-1930  1930 FIFA World Cup  M-1930-01
# 4       5  G-0005       WC-1930  1930 FIFA World Cup  M-1930-01
#
#         match_name  match_date   stage_name group_name team_id team_name  \
# 0  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 1  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 2  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 3  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 4  France v Mexico  1930-07-13  group stage    Group 1    T-44    Mexico
#
#   team_code  home_team  away_team player_id family_name given_name  \
# 0       FRA          1          0   P-09831     Laurent     Lucien
# 1       FRA          1          0   P-05670   Langiller     Marcel
# 2       FRA          1          0   P-07295   Maschinot      André
# 3       FRA          1          0   P-07295   Maschinot      André
# 4       MEX          0          1   P-03952     Carreño       Juan
#
#    shirt_number player_team_id player_team_name player_team_code minute_label  \
# 0             0           T-28           France              FRA          19'
# 1             0           T-28           France              FRA          40'
# 2             0           T-28           France              FRA          43'
# 3             0           T-28           France              FRA          87'
# 4             0           T-44           Mexico              MEX          70'
#
#    minute_regulation  minute_stoppage match_period  own_goal  penalty   team1  \
# 0                 19                0   first half         0        0  France
# 1                 40                0   first half         0        0  France
# 2                 43                0   first half         0        0  France
# 3                 87                0  second half         0        0  France
# 4                 70                0  second half         0        0  France
#
#     team2
# 0  Mexico
# 1  Mexico
# 2  Mexico
# 3  Mexico
# 4  Mexico

# %%
team1_first_goal_info=goals_data.groupby( [ 'tournament_id', 'match_id', 'team_name' ] ).agg( {'minute_regulation': 'min'} ).reset_index()
team1_first_goal_info=team1_first_goal_info.rename(columns={'team_name': 'team1', 'minute_regulation': 'team1_first_goal_minute'})
#team1_first_goal_info

# %%
goals_data = goals_data.merge( team1_first_goal_info, on=["tournament_id", "match_id", 'team1'], how='left' )
#goals_data.head(15)

# %%
goals_data = goals_data.rename( columns={ 'first_goal_minute': 'team1_first_goal_minute' } )
#goals_data.head()

# %%
team2_first_goal_info=goals_data.groupby( [ 'tournament_id', 'match_id', 'team_name' ] ).agg( {'minute_regulation': 'min'} ).reset_index()
team2_first_goal_info=team2_first_goal_info.rename(columns={'team_name': 'team2', 'minute_regulation': 'team2_first_goal_minute'})
team2_first_goal_info.head()
# Out:
#   tournament_id   match_id          team2  team2_first_goal_minute
# 0       WC-1930  M-1930-01         France                       19
# 1       WC-1930  M-1930-01         Mexico                       70
# 2       WC-1930  M-1930-02  United States                       23
# 3       WC-1930  M-1930-03         Brazil                       62
# 4       WC-1930  M-1930-03     Yugoslavia                       21

# %%
goals_data = goals_data.merge( team2_first_goal_info, on=["tournament_id", "match_id", 'team2'], how='left' )
goals_data.head()
# Out:
#    key_id goal_id tournament_id      tournament_name   match_id  \
# 0       1  G-0001       WC-1930  1930 FIFA World Cup  M-1930-01
# 1       2  G-0002       WC-1930  1930 FIFA World Cup  M-1930-01
# 2       3  G-0003       WC-1930  1930 FIFA World Cup  M-1930-01
# 3       4  G-0004       WC-1930  1930 FIFA World Cup  M-1930-01
# 4       5  G-0005       WC-1930  1930 FIFA World Cup  M-1930-01
#
#         match_name  match_date   stage_name group_name team_id team_name  \
# 0  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 1  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 2  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 3  France v Mexico  1930-07-13  group stage    Group 1    T-28    France
# 4  France v Mexico  1930-07-13  group stage    Group 1    T-44    Mexico
#
#   team_code  home_team  away_team player_id family_name given_name  \
# 0       FRA          1          0   P-09831     Laurent     Lucien
# 1       FRA          1          0   P-05670   Langiller     Marcel
# 2       FRA          1          0   P-07295   Maschinot      André
# 3       FRA          1          0   P-07295   Maschinot      André
# 4       MEX          0          1   P-03952     Carreño       Juan
#
#    shirt_number player_team_id player_team_name player_team_code minute_label  \
# 0             0           T-28           France              FRA          19'
# 1             0           T-28           France              FRA          40'
# 2             0           T-28           France              FRA          43'
# 3             0           T-28           France              FRA          87'
# 4             0           T-44           Mexico              MEX          70'
#
#    minute_regulation  minute_stoppage match_period  own_goal  penalty   team1  \
# 0                 19                0   first half         0        0  France
# 1                 40                0   first half         0        0  France
# 2                 43                0   first half         0        0  France
# 3                 87                0  second half         0        0  France
# 4                 70                0  second half         0        0  France
#
#     team2  team1_first_goal_minute  team2_first_goal_minute
# 0  Mexico                     19.0                     70.0
# 1  Mexico                     19.0                     70.0
# 2  Mexico                     19.0                     70.0
# 3  Mexico                     19.0                     70.0
# 4  Mexico                     19.0                     70.0

# %%
#goals_data.head(15)

# %%
goals_data.loc[ goals_data['team1_first_goal_minute'].isnull(), 'team1_first_goal_minute' ] = 200
goals_data.loc[ goals_data['team2_first_goal_minute'].isnull(), 'team2_first_goal_minute' ] = 200

#goals_data.head(15)

# %%
goals_data = goals_data[ [ 'tournament_id', 'team_name','match_id', 'team1', 'team2', 'team1_first_goal_minute', 'team2_first_goal_minute' ] ].drop_duplicates()

#goals_data.head(15)

# %%
goals_data['first_goal_country'] = goals_data['team1']

goals_data.loc[ ( goals_data['team1_first_goal_minute'] > goals_data['team2_first_goal_minute'] ), 'first_goal_country' ] = goals_data.loc[ ( goals_data['team1_first_goal_minute'] > goals_data['team2_first_goal_minute'] ), 'team2' ]

goals_data.head(35)
# Out:
#    tournament_id       team_name   match_id           team1          team2  \
# 0        WC-1930          France  M-1930-01          France         Mexico
# 4        WC-1930          Mexico  M-1930-01          France         Mexico
# 5        WC-1930   United States  M-1930-02   United States        Belgium
# 8        WC-1930      Yugoslavia  M-1930-03      Yugoslavia         Brazil
# 10       WC-1930          Brazil  M-1930-03      Yugoslavia         Brazil
# 11       WC-1930         Romania  M-1930-04         Romania           Peru
# 14       WC-1930            Peru  M-1930-04         Romania           Peru
# 15       WC-1930       Argentina  M-1930-05       Argentina         France
# 16       WC-1930           Chile  M-1930-06           Chile         Mexico
# 19       WC-1930      Yugoslavia  M-1930-07      Yugoslavia        Bolivia
# 23       WC-1930   United States  M-1930-08   United States       Paraguay
# 26       WC-1930         Uruguay  M-1930-09         Uruguay           Peru
# 27       WC-1930           Chile  M-1930-10           Chile         France
# 28       WC-1930       Argentina  M-1930-11       Argentina         Mexico
# 34       WC-1930          Mexico  M-1930-11       Argentina         Mexico
# 37       WC-1930          Brazil  M-1930-12          Brazil        Bolivia
# 41       WC-1930        Paraguay  M-1930-13        Paraguay        Belgium
# 42       WC-1930         Uruguay  M-1930-14         Uruguay        Romania
# 46       WC-1930       Argentina  M-1930-15       Argentina          Chile
# 49       WC-1930           Chile  M-1930-15       Argentina          Chile
# 50       WC-1930       Argentina  M-1930-16       Argentina  United States
# 56       WC-1930   United States  M-1930-16       Argentina  United States
# 57       WC-1930         Uruguay  M-1930-17         Uruguay     Yugoslavia
# 63       WC-1930      Yugoslavia  M-1930-17         Uruguay     Yugoslavia
# 64       WC-1930         Uruguay  M-1930-18         Uruguay      Argentina
# 68       WC-1930       Argentina  M-1930-18         Uruguay      Argentina
# 70       WC-1934         Austria  M-1934-01         Austria         France
# 73       WC-1934          France  M-1934-01         Austria         France
# 75       WC-1934  Czechoslovakia  M-1934-02  Czechoslovakia        Romania
# 77       WC-1934         Romania  M-1934-02  Czechoslovakia        Romania
# 78       WC-1934         Germany  M-1934-03         Germany        Belgium
# 83       WC-1934         Belgium  M-1934-03         Germany        Belgium
# 85       WC-1934         Hungary  M-1934-04         Hungary          Egypt
# 89       WC-1934           Egypt  M-1934-04         Hungary          Egypt
# 91       WC-1934           Italy  M-1934-05           Italy  United States
#
#     team1_first_goal_minute  team2_first_goal_minute first_goal_country
# 0                      19.0                     70.0             France
# 4                      19.0                     70.0             France
# 5                      23.0                    200.0      United States
# 8                      21.0                     62.0         Yugoslavia
# 10                     21.0                     62.0         Yugoslavia
# 11                      1.0                     75.0            Romania
# 14                      1.0                     75.0            Romania
# 15                     81.0                    200.0          Argentina
# 16                      3.0                    200.0              Chile
# 19                     60.0                    200.0         Yugoslavia
# 23                     10.0                    200.0      United States
# 26                     65.0                    200.0            Uruguay
# 27                     67.0                    200.0              Chile
# 28                      8.0                     42.0          Argentina
# 34                      8.0                     42.0          Argentina
# 37                     37.0                    200.0             Brazil
# 41                     40.0                    200.0           Paraguay
# 42                      7.0                    200.0            Uruguay
# 46                     12.0                     15.0          Argentina
# 49                     12.0                     15.0          Argentina
# 50                     20.0                     89.0          Argentina
# 56                     20.0                     89.0          Argentina
# 57                     18.0                      4.0         Yugoslavia
# 63                     18.0                      4.0         Yugoslavia
# 64                     12.0                     20.0            Uruguay
# 68                     12.0                     20.0            Uruguay
# 70                     44.0                     18.0             France
# 73                     44.0                     18.0             France
# 75                     50.0                     11.0            Romania
# 77                     50.0                     11.0            Romania
# 78                     25.0                     29.0            Germany
# 83                     25.0                     29.0            Germany
# 85                     11.0                     35.0            Hungary
# 89                     11.0                     35.0            Hungary
# 91                     18.0                     57.0              Italy

# %%
pd.set_option('display.max_rows', None)
winner_firstgoal_info=pd.merge(tournament_data[['tournament_id', 'first_goal_country']], goals_data, how='inner', on= ['tournament_id', 'first_goal_country' ])
#winner_firstgoal_info

# %%
winner_firstgoal_info = winner_firstgoal_info.groupby( [ 'tournament_id', 'first_goal_country' ] ).count()['match_id'].reset_index()

winner_firstgoal_info = winner_firstgoal_info.rename(columns={ 'match_id': 'number_of_matches_winner_scored_first' })
winner_firstgoal_info
# Out:
#    tournament_id first_goal_country  number_of_matches_winner_scored_first
# 0        WC-1930            Uruguay                                      4
# 1        WC-1934              Italy                                      4
# 2        WC-1938              Italy                                      8
# 3        WC-1950            Uruguay                                      3
# 4        WC-1954       West Germany                                      5
# 5        WC-1958             Brazil                                      5
# 6        WC-1962             Brazil                                      5
# 7        WC-1966            England                                      5
# 8        WC-1970             Brazil                                      7
# 9        WC-1974       West Germany                                      4
# 10       WC-1978          Argentina                                      6
# 11       WC-1982              Italy                                     11
# 12       WC-1986          Argentina                                      9
# 13       WC-1990       West Germany                                     12
# 14       WC-1994             Brazil                                      6
# 15       WC-1998             France                                      6
# 16       WC-2002             Brazil                                      6
# 17       WC-2006              Italy                                      7
# 18       WC-2010              Spain                                      7
# 19       WC-2014            Germany                                     10
# 20       WC-2018             France                                      9

# %%
non_winner_firstgoal_info = goals_data.merge( tournament_data[ [ 'tournament_id', 'first_goal_country' ] ], \
                      how='outer', left_on=['tournament_id', 'first_goal_country'], \
                      right_on=['tournament_id', 'first_goal_country'], indicator=True )

non_winner_firstgoal_info = non_winner_firstgoal_info.loc[ non_winner_firstgoal_info['_merge'] == 'left_only' ]

#non_winner_firstgoal_info

# %%
non_winner_firstgoal_info = non_winner_firstgoal_info.groupby( [ 'tournament_id', 'first_goal_country' ] ).count()['match_id'].reset_index()

non_winner_firstgoal_info = non_winner_firstgoal_info.rename(columns={ 'match_id': 'number_of_matches_non_winner_scored_first' })
non_winner_firstgoal_info
# Out:
#     tournament_id      first_goal_country  \
# 0         WC-1930               Argentina
# 1         WC-1930                  Brazil
# 2         WC-1930                   Chile
# 3         WC-1930                  France
# 4         WC-1930                Paraguay
# 5         WC-1930                 Romania
# 6         WC-1930           United States
# 7         WC-1930              Yugoslavia
# 8         WC-1934               Argentina
# 9         WC-1934                 Austria
# 10        WC-1934          Czechoslovakia
# 11        WC-1934                  France
# 12        WC-1934                 Germany
# 13        WC-1934                 Hungary
# 14        WC-1934                 Romania
# 15        WC-1934                   Spain
# 16        WC-1934             Switzerland
# 17        WC-1938                  Brazil
# 18        WC-1938          Czechoslovakia
# 19        WC-1938                  France
# 20        WC-1938                 Germany
# 21        WC-1938                 Hungary
# 22        WC-1938                 Romania
# 23        WC-1938                  Sweden
# 24        WC-1950                  Brazil
# 25        WC-1950                   Chile
# 26        WC-1950                 England
# 27        WC-1950                   Italy
# 28        WC-1950                   Spain
# 29        WC-1950                  Sweden
# 30        WC-1950             Switzerland
# 31        WC-1950           United States
# 32        WC-1950              Yugoslavia
# 33        WC-1954                 Austria
# 34        WC-1954                 Belgium
# 35        WC-1954                  Brazil
# 36        WC-1954                 England
# 37        WC-1954                  France
# 38        WC-1954                 Hungary
# 39        WC-1954                   Italy
# 40        WC-1954             Switzerland
# 41        WC-1954                  Turkey
# 42        WC-1954                 Uruguay
# 43        WC-1954              Yugoslavia
# 44        WC-1958               Argentina
# 45        WC-1958                 Austria
# 46        WC-1958          Czechoslovakia
# 47        WC-1958                  France
# 48        WC-1958                 Hungary
# 49        WC-1958        Northern Ireland
# 50        WC-1958                Paraguay
# 51        WC-1958            Soviet Union
# 52        WC-1958                  Sweden
# 53        WC-1958                   Wales
# 54        WC-1958            West Germany
# 55        WC-1958              Yugoslavia
# 56        WC-1962               Argentina
# 57        WC-1962                   Chile
# 58        WC-1962                Colombia
# 59        WC-1962          Czechoslovakia
# 60        WC-1962                 England
# 61        WC-1962                 Hungary
# 62        WC-1962                   Italy
# 63        WC-1962            Soviet Union
# 64        WC-1962                   Spain
# 65        WC-1962             Switzerland
# 66        WC-1962                 Uruguay
# 67        WC-1962            West Germany
# 68        WC-1962              Yugoslavia
# 69        WC-1966               Argentina
# 70        WC-1966                  Brazil
# 71        WC-1966                Bulgaria
# 72        WC-1966                   Chile
# 73        WC-1966                  France
# 74        WC-1966                 Hungary
# 75        WC-1966                   Italy
# 76        WC-1966                  Mexico
# 77        WC-1966             North Korea
# 78        WC-1966                Portugal
# 79        WC-1966            Soviet Union
# 80        WC-1966                   Spain
# 81        WC-1966             Switzerland
# 82        WC-1966            West Germany
# 83        WC-1970                 Belgium
# 84        WC-1970                Bulgaria
# 85        WC-1970          Czechoslovakia
# 86        WC-1970                 England
# 87        WC-1970                   Italy
# 88        WC-1970                  Mexico
# 89        WC-1970                 Morocco
# 90        WC-1970                    Peru
# 91        WC-1970            Soviet Union
# 92        WC-1970                  Sweden
# 93        WC-1970                 Uruguay
# 94        WC-1970            West Germany
# 95        WC-1974               Argentina
# 96        WC-1974                  Brazil
# 97        WC-1974                Bulgaria
# 98        WC-1974            East Germany
# 99        WC-1974                   Haiti
# 100       WC-1974             Netherlands
# 101       WC-1974                  Poland
# 102       WC-1974                Scotland
# 103       WC-1974                  Sweden
# 104       WC-1974              Yugoslavia
# 105       WC-1978                 Austria
# 106       WC-1978                  Brazil
# 107       WC-1978                  France
# 108       WC-1978                 Hungary
# 109       WC-1978                   Italy
# 110       WC-1978                  Mexico
# 111       WC-1978             Netherlands
# 112       WC-1978                    Peru
# 113       WC-1978                  Poland
# 114       WC-1978                Scotland
# 115       WC-1978                   Spain
# 116       WC-1978                  Sweden
# 117       WC-1978            West Germany
# 118       WC-1982                 Algeria
# 119       WC-1982               Argentina
# 120       WC-1982                 Austria
# 121       WC-1982                 Belgium
# 122       WC-1982                  Brazil
# 123       WC-1982          Czechoslovakia
# 124       WC-1982                 England
# 125       WC-1982                  France
# 126       WC-1982                Honduras
# 127       WC-1982                 Hungary
# 128       WC-1982        Northern Ireland
# 129       WC-1982                  Poland
# 130       WC-1982                Scotland
# 131       WC-1982            Soviet Union
# 132       WC-1982            West Germany
# 133       WC-1982              Yugoslavia
# 134       WC-1986                 Belgium
# 135       WC-1986                  Brazil
# 136       WC-1986                Bulgaria
# 137       WC-1986                 Denmark
# 138       WC-1986                 England
# 139       WC-1986                  France
# 140       WC-1986                 Hungary
# 141       WC-1986                   Italy
# 142       WC-1986                  Mexico
# 143       WC-1986                 Morocco
# 144       WC-1986        Northern Ireland
# 145       WC-1986                Paraguay
# 146       WC-1986                  Poland
# 147       WC-1986                Portugal
# 148       WC-1986                Scotland
# 149       WC-1986            Soviet Union
# 150       WC-1986                   Spain
# 151       WC-1986                 Uruguay
# 152       WC-1986            West Germany
# 153       WC-1990               Argentina
# 154       WC-1990                 Austria
# 155       WC-1990                 Belgium
# 156       WC-1990                  Brazil
# 157       WC-1990                Cameroon
# 158       WC-1990                Colombia
# 159       WC-1990              Costa Rica
# 160       WC-1990          Czechoslovakia
# 161       WC-1990                 England
# 162       WC-1990                   Italy
# 163       WC-1990             Netherlands
# 164       WC-1990                 Romania
# 165       WC-1990                Scotland
# 166       WC-1990            Soviet Union
# 167       WC-1990                   Spain
# 168       WC-1990                  Sweden
# 169       WC-1990                 Uruguay
# 170       WC-1990              Yugoslavia
# 171       WC-1994               Argentina
# 172       WC-1994                 Belgium
# 173       WC-1994                Bulgaria
# 174       WC-1994                Colombia
# 175       WC-1994                 Germany
# 176       WC-1994                   Italy
# 177       WC-1994                  Mexico
# 178       WC-1994             Netherlands
# 179       WC-1994                 Nigeria
# 180       WC-1994                  Norway
# 181       WC-1994     Republic of Ireland
# 182       WC-1994                 Romania
# 183       WC-1994                  Russia
# 184       WC-1994            Saudi Arabia
# 185       WC-1994                   Spain
# 186       WC-1994                  Sweden
# 187       WC-1994             Switzerland
# 188       WC-1994           United States
# 189       WC-1998               Argentina
# 190       WC-1998                 Belgium
# 191       WC-1998                  Brazil
# 192       WC-1998                Cameroon
# 193       WC-1998                   Chile
# 194       WC-1998                Colombia
# 195       WC-1998                 Croatia
# 196       WC-1998                 Denmark
# 197       WC-1998                 England
# 198       WC-1998                 Germany
# 199       WC-1998                    Iran
# 200       WC-1998                   Italy
# 201       WC-1998                 Jamaica
# 202       WC-1998                  Mexico
# 203       WC-1998                 Morocco
# 204       WC-1998             Netherlands
# 205       WC-1998                 Nigeria
# 206       WC-1998                  Norway
# 207       WC-1998                Paraguay
# 208       WC-1998                 Romania
# 209       WC-1998            South Africa
# 210       WC-1998             South Korea
# 211       WC-1998                   Spain
# 212       WC-1998                 Tunisia
# 213       WC-1998              Yugoslavia
# 214       WC-2002               Argentina
# 215       WC-2002                 Belgium
# 216       WC-2002                Cameroon
# 217       WC-2002              Costa Rica
# 218       WC-2002                 Denmark
# 219       WC-2002                 Ecuador
# 220       WC-2002                 England
# 221       WC-2002                 Germany
# 222       WC-2002                   Italy
# 223       WC-2002                   Japan
# 224       WC-2002                  Mexico
# 225       WC-2002                 Nigeria
# 226       WC-2002                Paraguay
# 227       WC-2002                  Poland
# 228       WC-2002                Portugal
# 229       WC-2002     Republic of Ireland
# 230       WC-2002                  Russia
# 231       WC-2002                 Senegal
# 232       WC-2002                Slovenia
# 233       WC-2002            South Africa
# 234       WC-2002             South Korea
# 235       WC-2002                   Spain
# 236       WC-2002                  Sweden
# 237       WC-2002                  Turkey
# 238       WC-2002           United States
# 239       WC-2006                  Angola
# 240       WC-2006               Argentina
# 241       WC-2006                  Brazil
# 242       WC-2006              Costa Rica
# 243       WC-2006                 Croatia
# 244       WC-2006          Czech Republic
# 245       WC-2006                 Ecuador
# 246       WC-2006                 England
# 247       WC-2006                  France
# 248       WC-2006                 Germany
# 249       WC-2006                   Ghana
# 250       WC-2006                   Japan
# 251       WC-2006                  Mexico
# 252       WC-2006             Netherlands
# 253       WC-2006                Paraguay
# 254       WC-2006                Portugal
# 255       WC-2006   Serbia and Montenegro
# 256       WC-2006                   Spain
# 257       WC-2006                  Sweden
# 258       WC-2006             Switzerland
# 259       WC-2006                    Togo
# 260       WC-2006                 Tunisia
# 261       WC-2006                 Ukraine
# 262       WC-2010               Argentina
# 263       WC-2010               Australia
# 264       WC-2010                  Brazil
# 265       WC-2010                Cameroon
# 266       WC-2010                   Chile
# 267       WC-2010                 England
# 268       WC-2010                 Germany
# 269       WC-2010                   Ghana
# 270       WC-2010             Ivory Coast
# 271       WC-2010                   Japan
# 272       WC-2010                  Mexico
# 273       WC-2010             Netherlands
# 274       WC-2010             New Zealand
# 275       WC-2010                 Nigeria
# 276       WC-2010                Paraguay
# 277       WC-2010                Portugal
# 278       WC-2010                  Serbia
# 279       WC-2010                Slovakia
# 280       WC-2010                Slovenia
# 281       WC-2010            South Africa
# 282       WC-2010             South Korea
# 283       WC-2010             Switzerland
# 284       WC-2010           United States
# 285       WC-2010                 Uruguay
# 286       WC-2014                 Algeria
# 287       WC-2014               Argentina
# 288       WC-2014                 Belgium
# 289       WC-2014  Bosnia and Herzegovina
# 290       WC-2014                  Brazil
# 291       WC-2014                   Chile
# 292       WC-2014                Colombia
# 293       WC-2014              Costa Rica
# 294       WC-2014                 Croatia
# 295       WC-2014                 Ecuador
# 296       WC-2014                  France
# 297       WC-2014                  Greece
# 298       WC-2014                Honduras
# 299       WC-2014                   Italy
# 300       WC-2014                   Japan
# 301       WC-2014                  Mexico
# 302       WC-2014             Netherlands
# 303       WC-2014                 Nigeria
# 304       WC-2014                Portugal
# 305       WC-2014                  Russia
# 306       WC-2014             South Korea
# 307       WC-2014                   Spain
# 308       WC-2014             Switzerland
# 309       WC-2014           United States
# 310       WC-2014                 Uruguay
# 311       WC-2018               Argentina
# 312       WC-2018                 Belgium
# 313       WC-2018                  Brazil
# 314       WC-2018                Colombia
# 315       WC-2018                 Croatia
# 316       WC-2018                 Denmark
# 317       WC-2018                   Egypt
# 318       WC-2018                 England
# 319       WC-2018                    Iran
# 320       WC-2018                   Japan
# 321       WC-2018                  Mexico
# 322       WC-2018                 Morocco
# 323       WC-2018                 Nigeria
# 324       WC-2018                  Panama
# 325       WC-2018                    Peru
# 326       WC-2018                  Poland
# 327       WC-2018                Portugal
# 328       WC-2018                  Russia
# 329       WC-2018                 Senegal
# 330       WC-2018                  Serbia
# 331       WC-2018             South Korea
# 332       WC-2018                   Spain
# 333       WC-2018                  Sweden
# 334       WC-2018             Switzerland
# 335       WC-2018                 Uruguay
#
#      number_of_matches_non_winner_scored_first
# 0                                            7
# 1                                            1
# 2                                            2
# 3                                            2
# 4                                            1
# 5                                            2
# 6                                            2
# 7                                            5
# 8                                            2
# 9                                            2
# 10                                           4
# 11                                           2
# 12                                           6
# 13                                           2
# 14                                           2
# 15                                           4
# 16                                           4
# 17                                           4
# 18                                           3
# 19                                           2
# 20                                           4
# 21                                           2
# 22                                           4
# 23                                           5
# 24                                          10
# 25                                           2
# 26                                           1
# 27                                           3
# 28                                           2
# 29                                           6
# 30                                           2
# 31                                           3
# 32                                           3
# 33                                           4
# 34                                           2
# 35                                           1
# 36                                           1
# 37                                           2
# 38                                           9
# 39                                           2
# 40                                           6
# 41                                           3
# 42                                           4
# 43                                           3
# 44                                           2
# 45                                           2
# 46                                           6
# 47                                           7
# 48                                           5
# 49                                           5
# 50                                           4
# 51                                           4
# 52                                           6
# 53                                           2
# 54                                           3
# 55                                           4
# 56                                           1
# 57                                           4
# 58                                           2
# 59                                           8
# 60                                           2
# 61                                           4
# 62                                           1
# 63                                           5
# 64                                           3
# 65                                           2
# 66                                           2
# 67                                           3
# 68                                           2
# 69                                           3
# 70                                           1
# 71                                           2
# 72                                           2
# 73                                           2
# 74                                           2
# 75                                           1
# 76                                           2
# 77                                           3
# 78                                           7
# 79                                           6
# 80                                           2
# 81                                           2
# 82                                           6
# 83                                           1
# 84                                           6
# 85                                           4
# 86                                           4
# 87                                           3
# 88                                           4
# 89                                           2
# 90                                           1
# 91                                           3
# 92                                           3
# 93                                           4
# 94                                           3
# 95                                           4
# 96                                           4
# 97                                           2
# 98                                           6
# 99                                           2
# 100                                          8
# 101                                          9
# 102                                          1
# 103                                          3
# 104                                          5
# 105                                          3
# 106                                          4
# 107                                          4
# 108                                          2
# 109                                          8
# 110                                          2
# 111                                          5
# 112                                          2
# 113                                          4
# 114                                          4
# 115                                          1
# 116                                          2
# 117                                          5
# 118                                          4
# 119                                          3
# 120                                          2
# 121                                          2
# 122                                          3
# 123                                          2
# 124                                          4
# 125                                          9
# 126                                          2
# 127                                          4
# 128                                          5
# 129                                          3
# 130                                          6
# 131                                          4
# 132                                          7
# 133                                          3
# 134                                          8
# 135                                          6
# 136                                          2
# 137                                          6
# 138                                          2
# 139                                          3
# 140                                          1
# 141                                          6
# 142                                          6
# 143                                          2
# 144                                          2
# 145                                          1
# 146                                          1
# 147                                          1
# 148                                          2
# 149                                          6
# 150                                          3
# 151                                          2
# 152                                          2
# 153                                          4
# 154                                          2
# 155                                          3
# 156                                          4
# 157                                          5
# 158                                          1
# 159                                          1
# 160                                          5
# 161                                          6
# 162                                          9
# 163                                          4
# 164                                          1
# 165                                          2
# 166                                          1
# 167                                          4
# 168                                          2
# 169                                          1
# 170                                          5
# 171                                          1
# 172                                          2
# 173                                          4
# 174                                          1
# 175                                          7
# 176                                          7
# 177                                          2
# 178                                          3
# 179                                          6
# 180                                          1
# 181                                          1
# 182                                          5
# 183                                          4
# 184                                          5
# 185                                          7
# 186                                          9
# 187                                          4
# 188                                          2
# 189                                          5
# 190                                          4
# 191                                          9
# 192                                          2
# 193                                          4
# 194                                          1
# 195                                          9
# 196                                          7
# 197                                          2
# 198                                          2
# 199                                          2
# 200                                          6
# 201                                          2
# 202                                          2
# 203                                          3
# 204                                          7
# 205                                          1
# 206                                          2
# 207                                          2
# 208                                          3
# 209                                          2
# 210                                          2
# 211                                          4
# 212                                          2
# 213                                          4
# 214                                          1
# 215                                          6
# 216                                          3
# 217                                          1
# 218                                          5
# 219                                          3
# 220                                          6
# 221                                          7
# 222                                          5
# 223                                          2
# 224                                          3
# 225                                          2
# 226                                          4
# 227                                          2
# 228                                          1
# 229                                          1
# 230                                          1
# 231                                          3
# 232                                          2
# 233                                          1
# 234                                          2
# 235                                          6
# 236                                          4
# 237                                          9
# 238                                          5
# 239                                          2
# 240                                          5
# 241                                          3
# 242                                          2
# 243                                          2
# 244                                          1
# 245                                          2
# 246                                          5
# 247                                          7
# 248                                          7
# 249                                          3
# 250                                          4
# 251                                          4
# 252                                          3
# 253                                          1
# 254                                          5
# 255                                          2
# 256                                          4
# 257                                          1
# 258                                          2
# 259                                          2
# 260                                          4
# 261                                          2
# 262                                          6
# 263                                          4
# 264                                          7
# 265                                          2
# 266                                          2
# 267                                          3
# 268                                          7
# 269                                          5
# 270                                          1
# 271                                          3
# 272                                          1
# 273                                          8
# 274                                          2
# 275                                          4
# 276                                          3
# 277                                          1
# 278                                          1
# 279                                          4
# 280                                          3
# 281                                          4
# 282                                          1
# 283                                          1
# 284                                          1
# 285                                          4
# 286                                          4
# 287                                          7
# 288                                          4
# 289                                          2
# 290                                          6
# 291                                          3
# 292                                          6
# 293                                          3
# 294                                          3
# 295                                          2
# 296                                          4
# 297                                          2
# 298                                          2
# 299                                          2
# 300                                          2
# 301                                          5
# 302                                          4
# 303                                          1
# 304                                          4
# 305                                          2
# 306                                          2
# 307                                          3
# 308                                          1
# 309                                          2
# 310                                          5
# 311                                          4
# 312                                          7
# 313                                          5
# 314                                          2
# 315                                          4
# 316                                          5
# 317                                          2
# 318                                          9
# 319                                          1
# 320                                          4
# 321                                          3
# 322                                          2
# 323                                          1
# 324                                          2
# 325                                          1
# 326                                          1
# 327                                          5
# 328                                          5
# 329                                          4
# 330                                          3
# 331                                          1
# 332                                          3
# 333                                          5
# 334                                          2
# 335                                          5

# %%
winner_firstgoal_info.describe()
# Out:
#        number_of_matches_winner_scored_first
# count                              21.000000
# mean                                6.619048
# std                                 2.438774
# min                                 3.000000
# 25%                                 5.000000
# 50%                                 6.000000
# 75%                                 8.000000
# max                                12.000000

# %%
non_winner_firstgoal_info.describe()
# Out:
#        number_of_matches_non_winner_scored_first
# count                                 336.000000
# mean                                    3.419643
# std                                     2.036847
# min                                     1.000000
# 25%                                     2.000000
# 50%                                     3.000000
# 75%                                     5.000000
# max                                    10.000000

# %%
#End of Data Transformation code
#Begin Visualization code

# %%
import matplotlib.pyplot as plt

# %%
#get non winner average to account for the count difference
non_winner_firstGoal_tourn_info = non_winner_firstgoal_info.groupby(['tournament_id']).agg( {'number_of_matches_non_winner_scored_first': 'mean'} ).reset_index()
non_winner_firstGoal_tourn_info.describe()
# Out:
#        number_of_matches_non_winner_scored_first
# count                                  21.000000
# mean                                    3.426266
# std                                     0.405978
# min                                     2.750000
# 25%                                     3.173913
# 50%                                     3.363636
# 75%                                     3.555556
# max                                     4.400000

# %%
winner_firstgoal_info.head()
tournaments = winner_firstgoal_info["tournament_id"].values
winner_firstGoal_count = winner_firstgoal_info["number_of_matches_winner_scored_first"].values

nonwinner_firstGoal_count=non_winner_firstGoal_tourn_info["number_of_matches_non_winner_scored_first"].values

# %%
#graph build and display
plt.figure(figsize=(10,10))
plt.bar(tournaments , winner_firstGoal_count, color="b", label = "Winner")
plt.bar(tournaments , nonwinner_firstGoal_count, color="r", label="Nonwinner Average")
plt.xlabel('Tournament')
plt.ylabel('Number of Games scored First')
plt.xticks(rotation=90)
plt.legend(loc='best')
plt.title('First Goals Scored')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(tournaments, winner_firstGoal_count , marker = "*",s =100, facecolors="yellow", edgecolors="black", label = "Winner")
plt.scatter(tournaments, nonwinner_firstGoal_count ,s =100, facecolors="red", edgecolors="black", label = "Nonwinner Average")
plt.ylim(0,13)
plt.xlabel("Tournaments")
plt.xticks(rotation=90)
plt.ylabel("Number of Games scored First")
plt.title("First Goals Scored")
plt.legend(loc='best')
plt.show()

# %%
from scipy import stats
stats.ttest_ind(winner_firstGoal_count,nonwinner_firstGoal_count)
# Out:
# Ttest_indResult(statistic=5.91795486415443, pvalue=6.164448464266307e-07)

# %%
stats.ttest_ind(winner_firstGoal_count,nonwinner_firstGoal_count, equal_var=False)
# Out:
# Ttest_indResult(statistic=5.917954864154428, pvalue=6.974384388739985e-06)
